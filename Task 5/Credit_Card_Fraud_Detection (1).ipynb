# %% [markdown]
# ##Author: Pratik Kumar Jha
# Task: Credit Card Fraud Detection

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card=pd.read_csv('/content/creditcard.csv')

# %%
credit_card.head(3)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
#
# [3 rows x 31 columns]

# %%
credit_card.tail(3)
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 150629  93798  1.963076  0.761481 -0.695665  3.900855  0.564233 -0.388571
# 150630  93798  0.000511  1.064202 -0.403154 -0.629699  1.218252 -0.233102
# 150631  93798 -0.796099  0.855510 -1.547924  0.276334  0.257263 -1.366656
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 150629  0.243059 -0.305132  0.169108  ...  0.067740  0.454708  0.056026
# 150630  0.870353 -0.143075  1.567454  ... -0.569978 -1.103569  0.041873
# 150631  0.124734       NaN       NaN  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# 150629 -0.183339  0.121210  0.100941 -0.073290 -0.059967    4.58    0.0
# 150630 -0.014577 -0.437402  0.065077  0.127707 -0.105725    5.25    0.0
# 150631       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [3 rows x 31 columns]

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150632 entries, 0 to 150631
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    150632 non-null  int64
#  1   V1      150632 non-null  float64
#  2   V2      150632 non-null  float64
#  3   V3      150632 non-null  float64
#  4   V4      150632 non-null  float64
#  5   V5      150632 non-null  float64
#  6   V6      150632 non-null  float64
#  7   V7      150632 non-null  float64
#  8   V8      150631 non-null  float64
#  9   V9      150631 non-null  float64
#  10  V10     150631 non-null  float64
#  11  V11     150631 non-null  float64
#  12  V12     150631 non-null  float64
#  13  V13     150631 non-null  float64
#  14  V14     150631 non-null  float64
#  15  V15     150631 non-null  float64
#  16  V16     150631 non-null  float64
#  17  V17     150631 non-null  float64
#  18  V18     150631 non-null  float64
#  19  V19     150631 non-null  float64
# ...

# %%
credit_card.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  150632.000000  150632.000000  150632.000000  150632.000000
# mean    54357.441281      -0.241951       0.039563       0.626443
# std     22079.490779       1.820806       1.612470       1.290487
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     39052.000000      -1.024734      -0.545888       0.121639
# 50%     55999.000000      -0.268150       0.117763       0.719971
# 75%     72876.000000       1.161285       0.801699       1.345372
# max     93798.000000       2.401777      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  150632.000000  150632.000000  150632.000000  150632.000000
# mean        0.129322      -0.249922       0.071603      -0.103569
# std         1.341313       1.313190       1.288432       1.165148
# min        -5.519697     -42.147898     -26.160506     -31.764946
# ...

# %%
credit_card.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card = credit_card.drop(112982)

# %%
credit_card.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
 credit_card['Class'].value_counts()
# Out:
# 0.0    150336
# 1.0       294
# Name: Class, dtype: int64

# %%
legit=credit_card[credit_card.Class==0]
fraud=credit_card[credit_card.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (150336, 31)
# (294, 31)

# %%
legit.Amount.describe()
# Out:
# count    150336.000000
# mean         89.060989
# std         242.886494
# min           0.000000
# 25%           5.800000
# 50%          22.800000
# 75%          79.150000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     294.000000
# mean      120.787653
# std       243.689320
# min         0.000000
# 25%         1.000000
# 50%        10.685000
# 75%       105.695000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare the values fotr both transaction
credit_card.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    54371.411398 -0.232075  0.032224  0.641218  0.120975 -0.243081
# 1.0    47016.714286 -5.295684  3.789179 -6.914529  4.396624 -3.758181
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.074527 -0.092695  0.054321 -0.057041  ...  0.040170 -0.040024
# 1.0   -1.430356 -5.663365  1.360196 -2.526687  ...  0.246076  1.250714
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.113078 -0.029453  0.012243  0.120345  0.022041  0.001145  0.002549
# 1.0   -0.293445 -0.093689 -0.111138  0.194626  0.062231  0.504392  0.094689
#
#            Amount
# Class
# 0.0     89.060989
# 1.0    120.787653
#
# [2 rows x 30 columns]

# %%
#compare the values fotr both transaction
credit_card.groupby('Class').median()
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    56018.0 -0.265614  0.116165  0.721955  0.150045 -0.288666 -0.185885
# 1.0    43431.5 -2.771628  2.701201 -4.499028  4.018037 -2.159427 -1.434471
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0   -0.051446  0.075292 -0.132654  ... -0.028296 -0.060241 -0.092411
# 1.0   -3.350226  0.734596 -2.302182  ...  0.294838  0.662314 -0.054004
#
#             V23       V24       V25       V26       V27       V28  Amount
# Class
# 0.0   -0.042596  0.066846  0.158241 -0.060917  0.011633  0.023210  22.800
# 1.0   -0.127344 -0.056857  0.217271 -0.038086  0.514799  0.180883  10.685
#
# [2 rows x 30 columns]

# %%
 #compare the values fotr both transaction
credit_card.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    54371.411398 -0.232075  0.032224  0.641218  0.120975 -0.243081
# 1.0    47016.714286 -5.295684  3.789179 -6.914529  4.396624 -3.758181
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.074527 -0.092695  0.054321 -0.057041  ...  0.040170 -0.040024
# 1.0   -1.430356 -5.663365  1.360196 -2.526687  ...  0.246076  1.250714
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.113078 -0.029453  0.012243  0.120345  0.022041  0.001145  0.002549
# 1.0   -0.293445 -0.093689 -0.111138  0.194626  0.062231  0.504392  0.094689
#
#            Amount
# Class
# 0.0     89.060989
# 1.0    120.787653
#
# [2 rows x 30 columns]

# %%
#compare the values fotr both transaction
credit_card.groupby('Class').median()
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    56018.0 -0.265614  0.116165  0.721955  0.150045 -0.288666 -0.185885
# 1.0    43431.5 -2.771628  2.701201 -4.499028  4.018037 -2.159427 -1.434471
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0   -0.051446  0.075292 -0.132654  ... -0.028296 -0.060241 -0.092411
# 1.0   -3.350226  0.734596 -2.302182  ...  0.294838  0.662314 -0.054004
#
#             V23       V24       V25       V26       V27       V28  Amount
# Class
# 0.0   -0.042596  0.066846  0.158241 -0.060917  0.011633  0.023210  22.800
# 1.0   -0.127344 -0.056857  0.217271 -0.038086  0.514799  0.180883  10.685
#
# [2 rows x 30 columns]

# %%
legit=legit.sample(n=241)

# %%
creditcard_data=pd.concat([legit,fraud],axis=0)

# %%
creditcard_data['Class'].value_counts()
# Out:
# 1.0    294
# 0.0    241
# Name: Class, dtype: int64

# %%
#compare the values for both transaction
credit_card.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    54371.411398 -0.232075  0.032224  0.641218  0.120975 -0.243081
# 1.0    47016.714286 -5.295684  3.789179 -6.914529  4.396624 -3.758181
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.074527 -0.092695  0.054321 -0.057041  ...  0.040170 -0.040024
# 1.0   -1.430356 -5.663365  1.360196 -2.526687  ...  0.246076  1.250714
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.113078 -0.029453  0.012243  0.120345  0.022041  0.001145  0.002549
# 1.0   -0.293445 -0.093689 -0.111138  0.194626  0.062231  0.504392  0.094689
#
#            Amount
# Class
# 0.0     89.060989
# 1.0    120.787653
#
# [2 rows x 30 columns]

# %%
#compare the values fotr both transaction
credit_card.groupby('Class').median()
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    56018.0 -0.265614  0.116165  0.721955  0.150045 -0.288666 -0.185885
# 1.0    43431.5 -2.771628  2.701201 -4.499028  4.018037 -2.159427 -1.434471
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0   -0.051446  0.075292 -0.132654  ... -0.028296 -0.060241 -0.092411
# 1.0   -3.350226  0.734596 -2.302182  ...  0.294838  0.662314 -0.054004
#
#             V23       V24       V25       V26       V27       V28  Amount
# Class
# 0.0   -0.042596  0.066846  0.158241 -0.060917  0.011633  0.023210  22.800
# 1.0   -0.127344 -0.056857  0.217271 -0.038086  0.514799  0.180883  10.685
#
# [2 rows x 30 columns]

# %%
x=creditcard_data.drop(columns='Class', axis=1)
y=creditcard_data['Class']
print(x)
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 93808   64594  1.212362  0.264560  0.265947  0.649223 -0.235425 -0.616324
# 120883  75994 -1.063080  0.394043  0.348015  0.852454  0.673427  0.021685
# 132951  80185 -2.494062  1.771509  1.041669  0.813327 -0.781895  0.652697
# 52084   45264  1.255760 -0.144373 -1.008024 -0.528532  1.933700  3.338554
# 123993  77142 -0.428613  0.117801  1.004555 -1.371452 -0.403028  1.359655
# ...       ...       ...       ...       ...       ...       ...       ...
# 149587  91524  1.954852  1.630056 -4.337200  2.378367  2.113348 -1.583851
# 149600  91554 -5.100256  3.633442 -3.843919  0.183208 -1.183997  1.602139
# 149869  92092 -1.108478  3.448953 -6.216972  3.021052 -0.529901 -2.551375
# 149874  92102 -1.662937  3.253892 -7.040485  2.266456 -4.177649 -0.746925
# 150601  93742 -3.291125  4.401194 -8.394212  4.453580 -4.790055 -4.240182
#
#               V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(y)
# Out:
# 93808     0.0
# 120883    0.0
# 132951    0.0
# 52084     0.0
# 123993    0.0
#          ...
# 149587    1.0
# 149600    1.0
# 149869    1.0
# 149874    1.0
# 150601    1.0
# Name: Class, Length: 535, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (535, 30) (428, 30) (107, 30)

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction,y_train)

# %%
print('Accuracy on training data ',training_data_accuracy)
# Out:
# Accuracy on training data  0.9485981308411215

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy=accuracy_score(x_test_prediction,y_test)

# %%
print('Accuracy on test data ',test_data_accuracy)
# Out:
# Accuracy on test data  0.9065420560747663

# %% [markdown]
# ##Hence the above task of Evaluating the given dataset to detect the credit card fradulation using python is performed successfully as a task as CodSoft Data Science Intern.
